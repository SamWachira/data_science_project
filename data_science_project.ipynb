# %% [markdown]
# The dataset used in this project contains information related to individuals across different regions of
# Somalia, focusing on their demographic details, education levels, access to healthcare
# facilities, and perceived barriers to healthcare

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data_url = "https://raw.githubusercontent.com/SamWachira/data_science_project/refs/heads/main/somalia_healthcare_access.csv"

df = pd.read_csv(data_url)
df.head()
# Out:
#   Region  Age  Gender Income_Level Education_Level  Access_to_Facility  \
# 0  Awdal   53  Female          Low         Primary                True
# 1  Awdal   35    Male         High       Secondary                True
# 2  Awdal   58    Male         High         Primary                True
# 3  Awdal   63    Male          Low       Secondary                True
# 4  Awdal   25  Female          Low         Primary                True
#
#    Distance_to_Facility_km Facility_Type  Quality_of_Care Health_Insurance  \
# 0                     6.30   Health Post              5.0            False
# 1                    84.62      Hospital              3.0             True
# 2                    76.40        Clinic              NaN             True
# 3                    84.92   Health Post              1.0             True
# 4                    72.12      Hospital              4.0             True
#
#                       Common_Health_Issues  Satisfaction_with_Healthcare  \
# ...
